# %%
from spectro.image import extract_patch, load_image_from_path, find_patch_position
import cv2
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from typing import Tuple
import cv2

# %%
img = load_image_from_path("../data/ambient.jpg")

# %%
plt.imshow(img)

# %%
patch_position = find_patch_position(img)

# %%
patch = extract_patch(img, patch_position)

# %%
plt.imshow(patch)

# %%
patch_position
# Out:
# (1970, 1571, 391, 349, 1.7357046604156494)
